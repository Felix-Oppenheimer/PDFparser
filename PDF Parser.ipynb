# %%
import pdfminer
import re
import string
import operator
from collections import Counter
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO

# %%
# Function converts pdf to text (string)
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text


# Function allows slicing dictioinary
def slicedict(d, s):
    return {k:v for k,v in d.iteritems() if k.startswith(s)}

# %%
# Converts pdf to lowercase string, strips whitespace and splits to a list of individual words
my_list = convert_pdf_to_txt("C:\Users\student10\Desktop\FnT CF Recsys Survey.pdf").lower().strip()
my_list = my_list.split()

# %%
# Data cleaning of punctuation and unwanted characters
new_list = [word.translate(None, string.punctuation) for word in my_list]
new_list = [word.translate(None, '\xe2\x80\x9d') for word in new_list]

# %%
# Clean list
new_list
# Out:
# ['foundations',
#  'and',
#  'trends',
#  'rcid1',
#  'in',
#  'human\x93computer',
#  'interaction',
#  'vol',
#  '4',
#  'no',
#  '2',
#  '2010',
#  '81\x93173',
#  'ccid1',
#  '2011',
#  'm',
#  'd',
#  'ekstrand',
#  'j',
#  't',
#  'riedl',
#  'and',
#  'j',
#  'a',
#  'konstan',
#  'doi',
#  '1015611100000009',
#  'collaborative',
#  'filtering',
#  'recommender',
#  'systems',
#  'by',
#  'michael',
#  'd',
#  'ekstrand',
#  'john',
#  't',
#  'riedl',
#  'and',
#  'joseph',
#  'a',
#  'konstan',
#  'contents',
#  '1',
#  'introduction',
#  '11',
#  'history',
#  'of',
#  'recommender',
#  'systems',
#  '12',
#  'core',
#  'concepts',
#  'vocabulary',
#  'and',
#  'notation',
#  '13',
#  'overview',
#  '2',
#  'collaborative',
#  'filtering',
#  'methods',
#  '21',
#  'baseline',
#  'predictors',
#  '22',
#  'user\x93user',
#  'collaborative',
#  'filtering',
#  '23',
#  'item\x93item',
#  'collaborative',
#  'filtering',
#  '24',
#  'dimensionality',
#  'reduction',
#  '25',
# ...

# %%
# Creates a dictionary of each word and the count of how many times it appears in the list
dictionary = Counter(new_list)

# %%
# Search the dictionary for the word you want to find 
slicedict(dictionary, raw_input())
# Out:
# therefore
# {'therefore': 30}

# %%
# Sort the dictionary in order of most common words
sorted_d = sorted(d.items(), key=operator.itemgetter(1), reverse=True)

# %%
# View the sorted dictionary
sorted_d
# Out:
# [('the', 1467),
#  ('of', 821),
#  ('a', 728),
#  ('to', 724),
#  ('and', 698),
#  ('in', 604),
#  ('for', 392),
#  ('is', 376),
#  ('user', 366),
#  ('be', 246),
#  ('users', 242),
#  ('ratings', 237),
#  ('with', 236),
#  ('as', 227),
#  ('items', 219),
#  ('are', 218),
#  ('recommender', 217),
#  ('that', 208),
#  ('on', 204),
#  ('can', 202),
#  ('by', 192),
#  ('or', 177),
#  ('this', 158),
#  ('it', 153),
#  ('acm', 150),
#  ('systems', 147),
#  ('data', 142),
#  ('have', 138),
#  ('item', 136),
#  ('pp', 131),
#  ('system', 126),
#  ('an', 122),
#  ('rating', 115),
#  ('recommendations', 110),
#  ('collaborative', 109),
#  ('j', 109),
#  ('they', 108),
#  ('not', 108),
#  ('recommendation', 105),
#  ('their', 105),
#  ('from', 103),
#  ('set', 99),
#  ('also', 96),
#  ('more', 94),
#  ('preference', 85),
#  ('\xef\xac\x81ltering', 83),
#  ('has', 82),
#  ('user\x99s', 80),
#  ('information', 78),
#  ('other', 78),
#  ('some', 77),
#  ('m', 76),
#  ('algorithms', 72),
# ...
